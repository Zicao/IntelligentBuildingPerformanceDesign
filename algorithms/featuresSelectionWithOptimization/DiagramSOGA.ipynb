# %%
import pandas as pd
import matplotlib.pyplot as plt
result_df=pd.read_csv('optienergy.dat',sep='\s+')

# %%
fig=plt.figure(figsize=(10,6))
ax1=result_df['obj_fn'].plot(label='SOGA',legend=True,color='red',figsize=(10,6))
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Prediction error')
plt.savefig("SOGA.jpg",dpi=600)

# %%
plt.show()
